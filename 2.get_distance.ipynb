# %% [markdown]
# ### Part 1: Basic Imports

# %%
import dask.dataframe as ddf
import dask.multiprocessing
import pandas as pd
import requests
from pprint import pprint
from tqdm import tqdm_notebook as tqdm
from time import sleep
pd.set_option('display.max_columns', None)

# %% [markdown]
# ###  Part 2: Read the data

# %%
stopbyroute = pd.read_csv('dump/StopDataByRoutes.csv', header=None)

# %%
stopbyroute.columns = ['Route', 'Order', 'Direction', 'Stopno', 'Address', 'SeqNumber', 'lat', 'long', 'seqNumberExt']

# %%
stopbyroute.head()
# Out:
#   Route  Order Direction  Stopno         Address  SeqNumber        lat  \
# 0   '1'     21         I      10  Parnell Square        220  53.353387
# 1   '1'     22         I      12       Dorset St        230  53.356789
# 2   '1'     23         I      14       Dorset St        240  53.358537
# 3   '1'     24         I      15       Dorset St        250  53.360251
# 4   '1'     25         I      17   Drumcondra Rd        260  53.363067
#
#        long  seqNumberExt
# 0 -6.265384           220
# 1 -6.264623           230
# 2 -6.262724           240
# 3 -6.260973           250
# 4 -6.258398           260

# %%
stopbyroute.shape
# Out:
# (10956, 9)

# %% [markdown]
# ###  Part 3: Create the last stop column and find the distance between present and last stop

# %% [markdown]
# The main idea is to first create a column for the last stop by looking up the last order number with same direction and route for every observation.
# After that, we'll self join the table to get the lat and long for the last stop.
#
# Then we'll query the OSRM to get the road distance between these two points.
# The reason we chose to get real data and not use the straight line formula is because the formula gives a very naive result and not that accurate to mimic the real-time scenario to get delay per km.

# %%
# get the details (name and coordinates) of last stop for every observation of step by route
def get_last(x):
    try:
        return stopbyroute[(stopbyroute.Direction == x.Direction) & (stopbyroute.Route == x.Route) & (stopbyroute.Order == x.Order-1)]['Stopno'].values[0]
    except:
        return None

# %%
stopbyroute['lastStop'] = stopbyroute.apply(lambda x: get_last(x), axis=1)

# %%
stopbyroute.shape
# Out:
# (10956, 10)

# %%
stopbyroute[(stopbyroute.Route == "'1'") & (stopbyroute.Direction == 'O')].sort_values('Order')
# Out:
#    Route  Order Direction  Stopno           Address  SeqNumber        lat  \
# 30   '1'      0         O     226      Shanard Road         10  53.391136
# 32   '1'      1         O     228       Shanliss Rd         20  53.391850
# 33   '1'      2         O     229       Shanliss Rd         30  53.391400
# 31   '1'      3         O     227       Shanliss Rd         40  53.391143
# 34   '1'      4         O     230       Shanliss Rd         50  53.389886
# 35   '1'      5         O     231       Swords Road         60  53.389236
# 77   '1'      6         O    1641       Swords Road         70  53.386524
# 78   '1'      7         O    1642       Swords Road         80  53.384000
# 21   '1'      8         O     213       Swords Road         90  53.381402
# 22   '1'      9         O     214       Swords Road        100  53.379309
# 80   '1'     10         O    4432       Swords Road        110  53.377207
# 17   '1'     11         O     119     Drumcondra Rd        120  53.375081
# 8    '1'     12         O      44     Drumcondra Rd        130  53.373016
# 83   '1'     13         O    7603     Drumcondra Rd        135  53.371593
# 9    '1'     14         O      45     Drumcondra Rd        140  53.369881
# 10   '1'     15         O      46     Drumcondra Rd        150  53.367147
# 11   '1'     16         O      47     Drumcondra Rd        160  53.363909
# 12   '1'     17         O      48     Drumcondra Rd        170  53.362322
# 13   '1'     18         O      49         Dorset St        180  53.359955
# 14   '1'     19         O      51         Dorset St        200  53.357816
# 15   '1'     20         O      52         Dorset St        210  53.356645
# 36   '1'     21         O     265    Parnell Square        220  53.353358
# 37   '1'     22         O     271      O'Connell St        230  53.348584
# 40   '1'     23         O     340       Townsend St        240  53.345970
# 41   '1'     24         O     350   Townsend Street        250  53.345647
# 42   '1'     25         O     351     Pearse Street        260  53.343394
# 43   '1'     26         O     352     Pearse Street        270  53.342974
# 44   '1'     27         O     353     Pearse Street        280  53.342615
# 45   '1'     28         O     354     Ringsend Road        290  53.342220
# 46   '1'     29         O     355     Ringsend Road        300  53.341795
# 47   '1'     30         O     356     Bridge Street        310  53.341903
# 48   '1'     31         O     357      Irishtown Rd        320  53.339167
# 66   '1'     32         O     390  Tritonville Road        330  53.337571
# 50   '1'     33         O     372     Sandymount Rd        340  53.335483
# 51   '1'     34         O     373     Sandymount Rd        350  53.334257
# 52   '1'     35         O     374     Sandymount Rd        360  53.333178
# 53   '1'     36         O     375       Seafort Ave        370  53.334001
# 79   '1'     37         O    2804       Strand Road        380  53.332324
# 54   '1'     38         O     376       Strand Road        390  53.330713
# 55   '1'     39         O     377       Strand Road        400  53.328743
# 56   '1'     40         O     378       Strand Road        410  53.325644
# 57   '1'     41         O     380   St. John's Road        420  53.324685
#
#         long  seqNumberExt  lastStop
# 30 -6.262192            10       NaN
# 32 -6.259797            20     226.0
# 33 -6.256516            30     228.0
# 31 -6.251322            40     229.0
# 34 -6.249051            50     227.0
# 35 -6.245927            60     230.0
# 77 -6.242370            70     231.0
# 78 -6.243600            80    1641.0
# 21 -6.244888            90    1642.0
# 22 -6.246649           100     213.0
# 80 -6.248545           110     214.0
# 17 -6.250821           120    4432.0
# 8  -6.252110           130     119.0
# 83 -6.253136           135      44.0
# 9  -6.254133           140    7603.0
# 10 -6.255359           150      45.0
# 11 -6.257276           160      46.0
# 12 -6.258764           170      47.0
# 13 -6.260865           180      48.0
# 14 -6.263266           200      49.0
# 15 -6.264534           210      51.0
# 36 -6.262030           220      52.0
# 37 -6.259539           230     265.0
# 40 -6.256140           240     271.0
# 41 -6.249770           250     340.0
# 42 -6.245313           260     350.0
# 43 -6.242426           270     351.0
# 44 -6.239614           280     352.0
# 45 -6.236453           290     353.0
# 46 -6.233039           300     354.0
# 47 -6.226722           310     355.0
# 48 -6.223103           320     356.0
# 66 -6.222285           330     357.0
# 50 -6.219674           340     390.0
# 51 -6.217907           350     372.0
# 52 -6.216363           360     373.0
# 53 -6.214388           370     374.0
# 79 -6.210501           380     375.0
# 54 -6.209266           390    2804.0
# 55 -6.208824           400     376.0
# 56 -6.207305           410     377.0
# 57 -6.209213           420     378.0

# %%
stopbyroute_test = stopbyroute.merge(stopbyroute[['Route', 'Stopno', 'Direction', 'lat', 'long']], 
                                     left_on=['lastStop', 'Direction', 'Route'], 
                                     right_on=['Stopno', 'Direction', 'Route'],
                                     how='left',
                                     suffixes=['', '_last'])

# %%
stopbyroute_test.shape
# Out:
# (10956, 13)

# %%
assert(stopbyroute_test.shape[0] == stopbyroute.shape[0])

# %%
stopbyroute_test.head()
# Out:
#   Route  Order Direction  Stopno         Address  SeqNumber        lat  \
# 0   '1'     21         I      10  Parnell Square        220  53.353387
# 1   '1'     22         I      12       Dorset St        230  53.356789
# 2   '1'     23         I      14       Dorset St        240  53.358537
# 3   '1'     24         I      15       Dorset St        250  53.360251
# 4   '1'     25         I      17   Drumcondra Rd        260  53.363067
#
#        long  seqNumberExt  lastStop  Stopno_last   lat_last  long_last
# 0 -6.265384           220     278.0        278.0  53.351628  -6.261237
# 1 -6.264623           230      10.0         10.0  53.353387  -6.265384
# 2 -6.262724           240      12.0         12.0  53.356789  -6.264623
# 3 -6.260973           250      14.0         14.0  53.358537  -6.262724
# 4 -6.258398           260      15.0         15.0  53.360251  -6.260973

# %% [markdown]
# ### Part 4: Get distance between the present and the last stop using OSRM
#
#
# #### Get the distance using OSRM (need to put a delay to stop getting blocked)

# %%
dist = []
error_idx = []
for i in tqdm(range(stopbyroute_test.shape[0])):
    try:
        source_coordinates = str(stopbyroute_test.loc[i,'long'])+','+str(stopbyroute_test.loc[i,'lat'])+(';') 
        dest_coordinates = str(stopbyroute_test.loc[i,'long_last'])+','+str(stopbyroute_test.loc[i,'lat_last'])

        url =  'http://router.project-osrm.org/route/v1/driving/'+source_coordinates+dest_coordinates

        payload = {"steps":"true","geometries":"geojson"}
        response = requests.get(url,params=payload)
        data = response.json()

        dist.append(data['routes'][0]['distance']/1000)
    except:
        error_idx.append(i)
        dist.append(0)
    sleep(0.5)
# Out:
# HBox(children=(IntProgress(value=0, max=10956), HTML(value='')))

# %% [markdown]
# Once we get the data, the best way is to create a backup.

# %%
stopbyroute_test['dist'] = dist

# %%
stopbyroute_test.to_csv('stopbyroute_updated.csv', index=False)

# %%
stopbyroute_test[(stopbyroute_test.dist == 0) & (~stopbyroute_test.lat_last.isna())].shape
# Out:
# (40, 14)

# %% [markdown]
# #### Use the idx to retry on the error list
# The main idea on the previous step was to keep track of the index for which a distance could not be retrieved. This can happen due to many reasons. But we need to retry until the number of faulty indexes remain same. This can be done using a loop, but since the runtime is huge, we cannot afford to take that risk.

# %%
dist1 = dist

# %%
error_idx1 = []
for i in tqdm(error_idx):
    try:
        source_coordinates = str(stopbyroute_test.loc[i,'long'])+','+str(stopbyroute_test.loc[i,'lat'])+(';') 
        dest_coordinates = str(stopbyroute_test.loc[i,'long_last'])+','+str(stopbyroute_test.loc[i,'lat_last'])

        url =  'http://router.project-osrm.org/route/v1/driving/'+source_coordinates+dest_coordinates

        payload = {"steps":"true","geometries":"geojson"}
        response = requests.get(url,params=payload)
        data = response.json()

        dist1[i] = data['routes'][0]['distance']/1000
    except:
        error_idx1.append(i)
        dist1[i] = 0
    sleep(0.5)
# Out:
# HBox(children=(IntProgress(value=0, max=255), HTML(value='')))

# %%
len(error_idx) - len(error_idx1)
# Out:
# 24

# %%
stopbyroute_test['dist1'] = dist1

# %%
stopbyroute_test[(stopbyroute_test.dist1 == 0) & (~stopbyroute_test.lat_last.isna())].shape
# Out:
# (16, 15)

# %% [markdown]
# #### Perform another manual to retry on the error list

# %%
dist2 = dist1

# %%
error_idx2 = []
for i in tqdm(error_idx1):
    try:
        source_coordinates = str(stopbyroute_test.loc[i,'long'])+','+str(stopbyroute_test.loc[i,'lat'])+(';') 
        dest_coordinates = str(stopbyroute_test.loc[i,'long_last'])+','+str(stopbyroute_test.loc[i,'lat_last'])

        url =  'http://router.project-osrm.org/route/v1/driving/'+source_coordinates+dest_coordinates

        payload = {"steps":"true","geometries":"geojson"}
        response = requests.get(url,params=payload)
        data = response.json()

        dist2[i] = data['routes'][0]['distance']/1000
    except:
        error_idx2.append(i)
        dist2[i] = 0
    sleep(0.5)
# Out:
# HBox(children=(IntProgress(value=0, max=231), HTML(value='')))

# %%
len(error_idx1) - len(error_idx2)
# Out:
# 0

# %% [markdown]
# Since the difference between the last two error lists is 0, it means even after running n number of retries, things won't change. So, giving up and proceeding further is by getting the rows for which no data was fetched.

# %%
stopbyroute_test[(stopbyroute_test.dist1 == 0) & (~stopbyroute_test.lat_last.isna())]
# Out:
#      Route  Order Direction  Stopno          Address  SeqNumber        lat  \
# 8910  '69'     52         O    4557        Rathcoole        540  53.281308
# 8913  '69'     32         O    4665     Convent Road        330  53.317234
# 8914  '69'     33         O    4666      Fonthill Rd        340  53.316819
# 8915  '69'     34         O    4667      Fonthill Rd        350  53.317476
# 8916  '69'     27         I    4672      Fonthill Rd        280  53.317547
# 8917  '69'     29         I    4673     Convent Road        300  53.318097
# 8918  '69'      1         O    4720       Aston Quay         20  53.346615
# 8919  '69'     15         I    5022    Kingswood Ave        160  53.293379
# 8920  '69'     17         I    5119   Kingswood Road        180  53.297898
# 8921  '69'     18         I    5120   Kingswood Road        190  53.300760
# 8922  '69'     19         I    5121  Green Isle Road        200  53.304470
# 8923  '69'     20         I    5122  Green Isle Road        210  53.306974
# 8924  '69'     40         O    5123  Green Isle Road        410  53.307047
# 8925  '69'     41         O    5124  Green Isle Road        420  53.304286
# 8926  '69'     42         O    5125   Kingswood Road        430  53.298500
# 8927  '69'     55         O    5126        Rathlawns        570  53.277334
#
#           long  seqNumberExt  lastStop  Stopno_last   lat_last  long_last  \
# 8910 -6.469668           540    3440.0       3440.0  53.281816  -6.465497
# 8913 -6.395502           330    2161.0       2161.0  53.318366  -6.394926
# 8914 -6.398038           340    4665.0       4665.0  53.317234  -6.395502
# 8915 -6.401319           350    4666.0       4666.0  53.316819  -6.398038
# 8916 -6.401094           280    2170.0       2170.0  53.317359  -6.403361
# 8917 -6.395162           300    3465.0       3465.0  53.316761  -6.395815
# 8918 -6.260275            20    4495.0       4495.0  53.346183  -6.256966
# 8919 -6.422841           160    3438.0       3438.0  53.291424  -6.428024
# 8920 -6.420124           180    6002.0       6002.0  53.295088  -6.418499
# 8921 -6.418611           190    5119.0       5119.0  53.297898  -6.420124
# 8922 -6.413912           200    5120.0       5120.0  53.300760  -6.418611
# 8923 -6.407339           210    5121.0       5121.0  53.304470  -6.413912
# 8924 -6.406958           410    6003.0       6003.0  53.309992  -6.403648
# 8925 -6.414237           420    5123.0       5123.0  53.307047  -6.406958
# 8926 -6.419425           430    5124.0       5124.0  53.304286  -6.414237
# 8927 -6.480014           570    4560.0       4560.0  53.279488  -6.477508
#
#       dist  dist1
# 8910   0.0    0.0
# 8913   0.0    0.0
# 8914   0.0    0.0
# 8915   0.0    0.0
# 8916   0.0    0.0
# 8917   0.0    0.0
# 8918   0.0    0.0
# 8919   0.0    0.0
# 8920   0.0    0.0
# 8921   0.0    0.0
# 8922   0.0    0.0
# 8923   0.0    0.0
# 8924   0.0    0.0
# 8925   0.0    0.0
# 8926   0.0    0.0
# 8927   0.0    0.0

# %% [markdown]
# #### Manually fill the 16 rows

# %% [markdown]
# Since only 16 rows are there, we can fill them manually. But taking a deep insight into the co-ordinates from OSRM, we see these rows indicate that it is not a feasible route. So, the 'dist2' column in the best suited one and we are ready with it for analysis.

# %%
# doing a sanity check. dist2 is completely fine and in sync with dist1
# after looking a the resukts, we see that the route '77A' is filled prefectly. Route '69' is still having the issues as seen above. So, we think it will be best if we drop this route form the analysis.
stopbyroute_test[stopbyroute_test.dist != stopbyroute_test.dist1]
# Out:
#       Route  Order Direction  Stopno            Address  SeqNumber        lat  \
# 8893   '69'     48         O    3453          Mill Road        500  53.282951
# 8894   '69'     10         I    3454          Mill Road        110  53.281645
# 8895   '69'     11         I    3455    Saggart Village        120  53.280342
# 8896   '69'     12         I    3456       Garters Lane        130  53.283513
# 8897   '69'     13         I    3457       Garters Lane        140  53.290012
# 8898   '69'     21         I    3461          Boot Road        220  53.309639
# 8899   '69'     28         I    3465       Convent Road        290  53.316761
# 8900   '69'     25         O    4379          Naas Road        260  53.316296
# 8901   '69'     41         I    4406          Naas Road        430  53.328041
# 8902   '69'     52         I    4408     Conyngham Road        540  53.348327
# 8903   '69'     32         I    4409       Orchard Road        330  53.322327
# 8904   '69'     44         O    4438      Kingswood Ave        450  53.293257
# 8906   '69'     22         I    4532     Hazelwood Cres        230  53.312033
# 8907   '69'     23         I    4534    Park View Lawns        240  53.313121
# 8908   '69'     24         I    4535    St. John's Lawn        250  53.315643
# 8909   '69'     38         O    4536     Hazelwood Cres        390  53.312107
# 8911   '69'     54         O    4560       Johnstown Rd        560  53.279488
# 9498  '77A'     50         I    2188       Crumlin Road        500  53.329014
# 9500  '77A'     54         I    2190     Dolphin's Barn        540  53.332950
# 9501  '77A'      8         O    2310    Werburgh Street         90  53.342448
# 9502  '77A'      9         O    2311       Kevin Street        100  53.338300
# 9503  '77A'     10         O    2312  St. Luke's Avenue        110  53.338875
# 9504  '77A'     11         O    2313  St. Luke's Avenue        120  53.338744
# 9505  '77A'     12         O    2314        Cork Street        130  53.338354
#
#           long  seqNumberExt  lastStop  Stopno_last   lat_last  long_last  \
# 8893 -6.452800           500    3434.0       3434.0  53.280311  -6.444680
# 8894 -6.447669           110    7432.0       7432.0  53.281891  -6.450144
# 8895 -6.444804           120    3454.0       3454.0  53.281645  -6.447669
# 8896 -6.440945           130    3455.0       3455.0  53.280342  -6.444804
# 8897 -6.438245           140    3456.0       3456.0  53.283513  -6.440945
# 8898 -6.404421           220    5122.0       5122.0  53.306974  -6.407339
# 8899 -6.395815           290    4672.0       4672.0  53.317547  -6.401094
# 8900 -6.373706           260    1960.0       1960.0  53.320165  -6.361967
# 8901 -6.338472           430    1981.0       1981.0  53.326467  -6.344890
# 8902 -6.301091           540    1472.0       1472.0  53.348427  -6.305953
# 8903 -6.393116           330    2159.0       2159.0  53.323217  -6.393865
# 8904 -6.422709           450    6001.0       6001.0  53.294799  -6.418596
# 8906 -6.405244           230    3461.0       3461.0  53.309639  -6.404421
# 8907 -6.408226           240    4532.0       4532.0  53.312033  -6.405244
# 8908 -6.407991           250    4534.0       4534.0  53.313121  -6.408226
# 8909 -6.405462           390    2168.0       2168.0  53.313802  -6.408631
# 8911 -6.477508           560    3441.0       3441.0  53.281179  -6.472836
# 9498 -6.302906           500    2187.0       2187.0  53.328038  -6.307261
# 9500 -6.292304           540    3952.0       3952.0  53.331658  -6.294516
# 9501 -6.269795            90    1934.0       1934.0  53.344123  -6.265520
# 9502 -6.270500           100    2310.0       2310.0  53.342448  -6.269795
# 9503 -6.275476           110    2311.0       2311.0  53.338300  -6.270500
# 9504 -6.278466           120    2312.0       2312.0  53.338875  -6.275476
# 9505 -6.280816           130    2313.0       2313.0  53.338744  -6.278466
#
#       dist   dist1
# 8893   0.0  0.7149
# 8894   0.0  0.1681
# 8895   0.0  0.3024
# 8896   0.0  0.4565
# 8897   0.0  0.7544
# 8898   0.0  0.3599
# 8899   0.0  0.4503
# 8900   0.0  2.9333
# 8901   0.0  1.2996
# 8902   0.0  0.3227
# 8903   0.0  0.6903
# 8904   0.0  0.3213
# 8906   0.0  0.4176
# 8907   0.0  0.2643
# 8908   0.0  0.3364
# 8909   0.0  0.3422
# 8911   0.0  0.4205
# 9498   0.0  0.3090
# 9500   0.0  0.2876
# 9501   0.0  0.9402
# 9502   0.0  0.8759
# 9503   0.0  0.3810
# 9504   0.0  0.1979
# 9505   0.0  0.1658

# %%
stopbyroute_test.to_csv('stopbyroute_updated1.csv', index=False)

# %% [markdown]
# #### Removing route 69 from the observations
#
# We have found out from the last to last observation that most of the stops of route 69 is faulty. So, the decision we take here is to completely remove the route from our analysis.

# %%
stopbyroute_test1 = stopbyroute_test.copy()

# %%
stopbyroute_test1 = stopbyroute_test1[stopbyroute_test1.Route!="'69'"]

# %%
stopbyroute_test1.shape
# Out:
# (10839, 15)

# %%
stopbyroute_test1.drop('dist', axis=1, inplace=True)

# %%
stopbyroute_test1.to_csv('stopbyroute_updated_final.csv', index=False)
